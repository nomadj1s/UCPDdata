# %% [markdown]
# # UCPD Data Scrape

# %% [markdown]
# ## Import Things

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## Get Field Interview Data

# %%
# Get headers

url0 = ('https://incidentreports.uchicago.edu/fieldInterviewsArchive.php?' +
       'startDate=1433134800&endDate=1597208400&offset=5')

# Get url contents
page0 = requests.get(url0)

# Store contents
soup0 = bs(page0.text, 'lxml')

# Get table data
table_rows0 = soup0.find('table').find_all('tr')

headers0 = [i.text for i in table_rows0[0].find_all(['th'])]

# Use Loop to get data
data0 = []

for n in range(363):
    offset = n*5
    
    # Get url
    url = ('https://incidentreports.uchicago.edu/fieldInterviewsArchive.php?' +
           'startDate=1433134800&endDate=1597208400&offset=' + str(offset))
    
    # Get url contents
    page = requests.get(url)
    
    # Store contents
    soup = bs(page.text, 'lxml')
    
    # Get table data
    table_rows = soup.find('table').find_all('tr')
    
    # Get data
    data_n = [[i.text for i in tr.find_all(['td','th'])] 
              for tr in table_rows
              if not any(x in tr.find_all(['td','th'])[0].text 
                         for x in ['Date','field inter'])]
    
    data0 = data0 + data_n

# %% [markdown]
# ### Create Data Frame

# %%
df = pd.DataFrame(data0, columns = headers0)

# Export Raw Data
df.to_csv(r'data_field_raw.csv',index = False)

df
# Out:
#              Date/Time              Location  \
# 0     6/3/2015 1:40 PM           1601 E 53rd
# 1     6/3/2015 1:40 PM           1601 E 53rd
# 2     6/4/2015 8:21 PM  5245 S Cottage Grove
# 3    6/4/2015 10:01 PM     901 E 58th Street
# 4    6/4/2015 10:01 PM     901 E 58th Street
# ..                 ...                   ...
# 750   7/6/2020 1:24 AM       5472 S. Kenwood
# 751   7/6/2020 1:24 AM       5472 S. Kenwood
# 752   7/6/2020 1:24 AM       5472 S. Kenwood
# 753   7/6/2020 1:24 AM       5472 S. Kenwood
# 754   8/2/2020 8:24 AM         5400 S. Shore
#
#                           Initiated By              Race  Gender  \
# 0    Citizen request for UCPD Response  African American  Female
# 1    Citizen request for UCPD Response  African American    Male
# 2    Citizen request for UCPD Response  African American    Male
# 3                                 UCPD  African American    Male
# 4                                 UCPD  African American  Female
# ..                                 ...               ...     ...
# 750                               UCPD  African American    Male
# 751                               UCPD  African American    Male
# 752                               UCPD  African American    Male
# 753                               UCPD  African American    Male
# 754                               UCPD  African American    Male
#
#                                        Reason for Stop  \
# 0    Citizen observed subject having a verbal argum...
# 1    Citizen observed subject having a verbal argum...
# 2    Complainant advised subject acted suspicious (...
# 3    Disturbance - Domestic Incident, prior inciden...
# 4    Disturbance - Domestic Incident, prior inciden...
# ..                                                 ...
# 750    Matched description of armed  robbery offenders
# 751    Matched description of armed  robbery offenders
# 752    Matched description of armed  robbery offenders
# 753    Matched description of armed  robbery offenders
# 754  Suspicious vehicle with occupants observed wit...
#
#                          Disposition Search
# 0    Name checked; no further action     No
# 1    Name checked; no further action     No
# 2    Name checked; no further action     No
# 3    Name checked; no further action     No
# 4      Name checked; arrested by CPD     No
# ..                               ...    ...
# 750              Released to parents    Yes
# 751              Released to parents    Yes
# 752              Released to parents    Yes
# 753              Released to parents    Yes
# 754     Name checked clear, released    Yes
#
# [755 rows x 8 columns]

# %% [markdown]
# ### Clean Data

# %%
# One Row has location (Ellis) in Date/Time, seems to have been on 8/6/2018

badRow = df['Date/Time'].str.contains('Ellis')

badData = df.loc[badRow,'Date/Time'].values[0]

## shift data over by 1

df[badRow] = df[badRow].shift(1,axis=1)

## Fill in corrected data

df.loc[badRow,['Date/Time','Location']] = ['8/6/2018 ' 
                                           + badData[:badData.find("PM") + 2],
                                           badData[badData.find("PM") + 3:]]

# Two more rows have data shifted to the left, shift to the right

badRow2 = df['Race'].isin(['Male','Female'])

df.loc[badRow2,df.columns[2:-2]] = df.loc[badRow2,
                                          df.columns[2:-2]].shift(1,axis=1)

# Clean value of African American
df = df.replace(['African\nAmerican'],'African American')

# Export Clean Data
df.to_csv(r'data_field.csv',index = False)

# %% [markdown]
# ### Calculate Statistics

# %%
counts = df['Race'].value_counts()
percent = df['Race'].value_counts(normalize=True)
pd.DataFrame({'counts': counts, 'percent': percent})
# Out:
#                   counts   percent
# African American     697  0.943166
# Caucasian             30  0.040595
# Hispanic              12  0.016238

# %% [markdown]
# ## Get Traffic Stop Data

# %%
# Get headers

url1 = ('https://incidentreports.uchicago.edu/trafficStopsArchive.php?' +
       'startDate=1433134800&endDate=1597208400&offset=5')

# Get url contents
page1 = requests.get(url1)

# Store contents
soup1 = bs(page1.text, 'lxml')

# Get table data
table_rows1 = soup1.find('table').find_all('tr')

headers1 = [i.text for i in table_rows1[0].find_all(['th'])]

# Use Loop to get data
data1 = []

for n in range(987):
    offset = n*5
    
    # Get url
    url = ('https://incidentreports.uchicago.edu/trafficStopsArchive.php?' +
           'startDate=1433134800&endDate=1597208400&offset=' + str(offset))
    
    # Get url contents
    page = requests.get(url)
    
    # Store contents
    soup = bs(page.text, 'lxml')
    
    # Get table data
    table_rows = soup.find('table').find_all('tr')
    
    # Get data
    data_n = [[i.text for i in tr.find_all(['td','th'])] 
              for tr in table_rows
              if not any(x in tr.find_all(['td','th'])[0].text 
                         for x in ['Date','traffic','stops'])]
    
    data1 = data1 + data_n

# %% [markdown]
# ### Create Data Frame

# %%
df1 = pd.DataFrame(data1, columns = headers1)

# Export Raw Data
df1.to_csv(r'data_traffic_raw.csv',index = False)

df1
# Out:
#                Date/Time              Location              Race  Gender  \
# 0       6/3/2015 9:26 AM   5600 S Stony Island  African American  Female
# 1       6/4/2015 5:44 PM          5900 S Ellis  African American  Female
# 2     6/27/2015 11:36 AM  6121 S Cottage Grove  African American    Male
# 3     7/11/2015 10:04 PM  5500 S Cottage Grove  African American    Male
# 4     7/11/2015 10:47 PM         5600 S Drexel  African American    Male
# ...                  ...                   ...               ...     ...
# 4473  8/10/2020 12:44 PM     6200 S. Greenwood  African American    Male
# 4474   8/11/2020 9:06 PM    5300 S. University  African American    Male
# 4475  8/11/2020 11:05 PM   1412 E. 53rd Street  African American    Male
# 4476   8/12/2020 4:56 PM   1455 E. 53rd Street  African American    Male
# 4477   8/12/2020 9:41 PM    5400 S. Blackstone  African American  Female
#
#            IDOT Classification  \
# 0          Traffic Sign/Signal
# 1             Follow Too Close
# 2               Lane Violation
# 3     Moving Violation - Other
# 4               Lane Violation
# ...                        ...
# 4473       Traffic sign/signal
# 4474       Traffic sign/signal
# 4475            Lane Violation
# 4476            Lane Violation
# 4477       Traffic sign/signal
#
#                                         Reason for Stop Citations/Violations  \
# 0     Stop Sign Violation, Failed to Yield to Pedest...                  N/A
# 1     Following too closely to vehicle stopped for p...                  N/A
# 2     Subject was driving erratically and cut off an...                  N/A
# 3                      Failed to yield to CFD firetruck                  N/A
# 4                             Wrong way on one way road                  N/A
# ...                                                 ...                  ...
# 4473  Disobey stop sign and failure to give right of...                  N/A
# 4474                                Disobeyed Stop Sign                  N/A
# 4475                        Wrong way on one way street  One Citation Issued
# 4476                        Wrong way on one way street                  N/A
# 4477  The motorist was observed disregarding a stop ...                  N/A
#
#           Disposition Search
# 0      Verbal Warning     No
# 1      Verbal Warning     No
# 2      Verbal Warning     No
# 3      Verbal Warning     No
# 4      Verbal Warning     No
# ...               ...    ...
# 4473   Verbal Warning     NO
# 4474   Verbal Warning     NO
# 4475  Citation Issued     NO
# 4476   Verbal Warning     NO
# 4477   Verbal Warning     NO
#
# [4478 rows x 9 columns]

# %% [markdown]
# ### Clean Data

# %%
# Two rows have location in Date/Time, happening between 1/24/17-1/31/17

badRow3 = df1['Race'].isin(['Male','Female'])

## Reorganize columns
df1.loc[badRow3,'Race':] = df1.loc[badRow3,['Location','Race',
                                            'Reason for Stop','Gender',
                                            'Search','IDOT Classification',
                                            'Citations/Violations']].values

## Set Date to arbitrary date between 1/24/17 and 1/31/17
df1.loc[badRow3,'Location'] = df1.loc[badRow3,'Date/Time'].str[8:]
df1.loc[badRow3,'Date/Time'] = '1/27/2017 ' + df1.loc[badRow3,
                                                      'Date/Time'].str[:7]

# Harmonize Race variable
df1.loc[df1['Race'].str.count(' ') == 0,
        'Race'] = df1.loc[df1['Race'].str.count(' ') == 0,
                          'Race'].str.capitalize()
df1.loc[df1['Race'].str.contains('African',na=False),
        'Race'] = 'African American'
df1.loc[df1['Race'].str.contains('Indian',na=False),
        'Race'] = 'American Indian/Alaskan Native'

# Export Clean Data
df1.to_csv(r'data_traffic.csv',index = False)

# %% [markdown]
# ### Calculate Statistics

# %%
counts1 = df1['Race'].value_counts()
percent1 = df1['Race'].value_counts(normalize=True)
pd.DataFrame({'counts': counts1, 'percent': percent1})
# Out:
#                                         counts   percent
# African American                          3278  0.732023
# Caucasian                                  741  0.165476
# Asian                                      226  0.050469
# Hispanic                                   217  0.048459
# American Indian/Alaskan Native              12  0.002680
# Native Hawaiian/Other Pacific Islander       4  0.000893
